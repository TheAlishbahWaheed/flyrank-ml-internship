# %% [markdown]
# <a href="https://colab.research.google.com/github/TheAlishbahWaheed/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/TheAlishbahWaheed/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane: Ranking Signal Analysis
#
# I chose the Ranking Signal Analysis lane because I want to understand which measurable content and search metrics are associated with stronger search performance. This lane matches my interest in machine learning and data analysis while allowing me to work with real-world anonymized SEO data. I hope to learn how data can support better content optimization decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# My research question is:
#
# "What measurable content and search metrics are associated with better search performance?"
#
# This work helps SEO analysts and content teams decide which pages should be prioritized for optimization. The goal is to support decisions using observed data patterns. A poor recommendation could waste time and resources by focusing on the wrong pages, resulting in missed opportunities for improving search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd

df = pd.read_csv("flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("\nColumn Names:")
print(df.columns.tolist())

print("\nMissing Values:")
print(df.isnull().sum().sort_values(ascending=False).head())

print("\nSummary Statistics:")
print(df.describe(include="all"))
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Rows: 30000
# Columns: 44
#
# Column Names:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#
# Missing Values:
# provider_used      21438
# word_count          7699
# char_count          7699
# word_count_tier     7699
# char_count_tier     7699
# dtype: int64
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## What I Can and Can't Claim
#
# This project will identify observed patterns and relationships in the anonymized search data. The findings can provide directional insights and decision-support for SEO analysts and content teams when deciding which pages or content may be worth optimizing.
#
# However, this project cannot prove that one factor directly causes better search rankings. It cannot predict Google's ranking algorithm or guarantee future search performance. All conclusions will be based only on the available dataset and should be interpreted as evidence for informed decision-making rather than causal proof.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ✅] Every section above is filled — markdown thinking AND the code that backs it
# - [ ✅] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ✅] No client names, URLs, or private queries anywhere
# - [✅ ] My claims use careful words: observed, measured, directional, decision-support
# - [✅ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# <a href="https://colab.research.google.com/github/TheAlishbahWaheed/flyrank-ml-internship/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/TheAlishbahWaheed/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the Search Performance Optimization lane. I am interested in understanding why some pages receive impressions but do not receive many clicks. This question is useful because improving search performance can help prioritize content updates and better allocate time and resources. I also chose this lane because the starter dataset already contains search-related metrics that can be analyzed with data and later supported by machine learning.

# %%
# This cell is for CODE (numbers, a query, a check).

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# My research question is: Which pages are likely underperforming relative to their search visibility and should be prioritized for optimization?
#
# The decision this work improves is deciding which pages should be optimized first. The people acting on this recommendation would be content teams, SEO teams, or website owners. The action they could take is updating page content, improving keywords, changing titles, or improving metadata.
#
# A wrong recommendation could cause teams to spend time improving pages that do not need attention while ignoring pages with higher potential impact. This would waste resources and reduce the value of optimization efforts.
#
# Machine learning may help because manually reviewing a large number of pages becomes difficult. A model could identify patterns and prioritize opportunities more efficiently, but the goal is decision support rather than automatic decision making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd

df = pd.read_csv("../data/starter_dataset.csv")  # replace with your actual file

print("Rows:", len(df))
print("Columns:", len(df.columns))
print(df.describe())
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2674/1660205332.py in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 df = pd.read_csv("../data/starter_dataset.csv")  # replace with your actual file
#       5
#       6 print("Rows:", len(df))
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project can identify observed patterns, measured relationships, and directional insights in the available data. The results may support decisions about where to focus optimization efforts.
#
# This project cannot prove causation, predict Google's behavior, or guarantee that a recommended action will improve performance. Any recommendations should be treated as decision-support information and validated before implementation.

# %%
# This cell is for CODE (numbers, a query, a check).
print("Unique pages:", df["page"].nunique())
print("Total impressions:", df["impressions"].sum())
print("Total clicks:", df["clicks"].sum())
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2674/3326562030.py in <cell line: 0>()
#       1 # This cell is for CODE (numbers, a query, a check).
# ----> 2 print("Unique pages:", df["page"].nunique())
#       3 print("Total impressions:", df["impressions"].sum())
#       4 print("Total clicks:", df["clicks"].sum())
#       5 # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
